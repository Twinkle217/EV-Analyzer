# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ****Phase 1****
# **Load Dataset**

# %%
df = pd.read_csv(r"C:/Users/Twinkle Parmar/Untitled Folder/electric_vehicles_spec_2025.csv.csv")
#print(df)
df.head(3)
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# 0                   7.0  ...                 0.0            185      4
# 1                   7.0  ...                 0.0            185      4
# 2                   5.9  ...                 0.0            360      5
#
#   drivetrain       segment length_mm width_mm  height_mm  car_body_type  \
# ...

# %% [markdown]
# ***Phase-2***
# **Data cleaning & PreProcessing**

# %%
missing_value = df.isnull().sum()
print(missing_value)
missing_cols = df.columns[df.isnull().sum() > 0]
print(missing_cols)
# Out:
# brand                          0
# model                          1
# top_speed_kmh                  0
# battery_capacity_kWh           0
# battery_type                   0
# number_of_cells              202
# torque_nm                      7
# efficiency_wh_per_km           0
# range_km                       0
# acceleration_0_100_s           0
# fast_charging_power_kw_dc      1
# fast_charge_port               1
# towing_capacity_kg            26
# cargo_volume_l                 1
# seats                          0
# drivetrain                     0
# segment                        0
# length_mm                      0
# width_mm                       0
# height_mm                      0
# car_body_type                  0
# source_url                     0
# dtype: int64
# Index(['model', 'number_of_cells', 'torque_nm', 'fast_charging_power_kw_dc',
#        'fast_charge_port', 'towing_capacity_kg', 'cargo_volume_l'],
#       dtype='object')

# %%
duplicate_data = df.duplicated().sum()
print(duplicate_data)
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      478 non-null    object
#  1   model                      477 non-null    object
#  2   top_speed_kmh              478 non-null    int64
#  3   battery_capacity_kWh       478 non-null    float64
#  4   battery_type               478 non-null    object
#  5   number_of_cells            276 non-null    float64
#  6   torque_nm                  471 non-null    float64
#  7   efficiency_wh_per_km       478 non-null    int64
#  8   range_km                   478 non-null    int64
#  9   acceleration_0_100_s       478 non-null    float64
#  10  fast_charging_power_kw_dc  477 non-null    float64
#  11  fast_charge_port           477 non-null    object
#  12  towing_capacity_kg         452 non-null    float64
# ...

# %%
df.describe()
# Out:
#        top_speed_kmh  battery_capacity_kWh  number_of_cells    torque_nm  \
# count     478.000000            478.000000       276.000000   471.000000
# mean      185.487448             74.043724       485.293478   498.012739
# std        34.252773             20.331058      1210.819733   241.461128
# min       125.000000             21.300000        72.000000   113.000000
# 25%       160.000000             60.000000       150.000000   305.000000
# 50%       180.000000             76.150000       216.000000   430.000000
# 75%       201.000000             90.600000       324.000000   679.000000
# max       325.000000            118.000000      7920.000000  1350.000000
#
#        efficiency_wh_per_km    range_km  acceleration_0_100_s  \
# count            478.000000  478.000000            478.000000
# mean             162.903766  393.179916              6.882636
# std               34.317532  103.287335              2.730696
# ...

# %%
missing_percent = df.isnull().sum() / len(df) * 100
print(missing_percent)
# Out:
# brand                         0.000000
# model                         0.209205
# top_speed_kmh                 0.000000
# battery_capacity_kWh          0.000000
# battery_type                  0.000000
# number_of_cells              42.259414
# torque_nm                     1.464435
# efficiency_wh_per_km          0.000000
# range_km                      0.000000
# acceleration_0_100_s          0.000000
# fast_charging_power_kw_dc     0.209205
# fast_charge_port              0.209205
# towing_capacity_kg            5.439331
# cargo_volume_l                0.209205
# seats                         0.000000
# drivetrain                    0.000000
# segment                       0.000000
# length_mm                     0.000000
# width_mm                      0.000000
# height_mm                     0.000000
# car_body_type                 0.000000
# source_url                    0.000000
# dtype: float64

# %%
numeric_col = df.select_dtypes(include=["int64","float64"]).columns
df[numeric_col]=df[numeric_col].fillna(df[numeric_col].median(numeric_only=True))
print("Missing Value after filling")
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing Value after filling
# model               1
# fast_charge_port    1
# cargo_volume_l      1
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include='object').columns
for col in categorical_cols:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].mode()[0])
print("Missing Value after filling")
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing Value after filling
# Series([], dtype: int64)

# %% [markdown]
# **To Download New Updated File**

# %%
df.to_csv("C:/Users/Twinkle Parmar/Untitled Folder/Electric_vehicale_updated.csv",index = False)

# %%
import os

print(os.path.exists("C:/Users/Twinkle Parmar/Untitled Folder/Electric_vehicale_updated.csv"))
# Out:
# True
